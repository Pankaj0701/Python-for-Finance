# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_datareader
from pandas_datareader import data as wb
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
tickers = ['^GSPC','^IXIC','^GDAXI','^FTSE']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = yf.download(t, start = '1995-1-1')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ind_data.head()
# Out:
#                  ^GSPC       ^IXIC       ^GDAXI        ^FTSE
# Date
# 1995-01-03  459.109985  743.580017  2068.919922  3065.699951
# 1995-01-04  460.709991  745.840027  2072.899902  3051.600098
# 1995-01-05  460.339996  745.659973  2051.459961  3032.300049
# 1995-01-06  460.679993  749.690002  2058.199951  3065.000000
# 1995-01-09  460.829987  752.090027  2053.409912  3055.800049

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI        ^FTSE
# Date
# 2025-08-18  6449.149902  21629.769531  24314.769531  9157.700195
# 2025-08-19  6411.370117  21314.949219  24423.070312  9189.200195
# 2025-08-20  6395.779785  21172.859375  24276.970703  9288.099609
# 2025-08-21  6370.169922  21100.310547  24293.339844  9309.200195
# 2025-08-22  6466.910156  21496.539062  24363.089844  9321.400391

# %%
(ind_data /ind_data.iloc[0]*100).plot(figsize=(15,6));

# %%
ind_returns = (ind_data / ind_data.shift(1))-1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI     ^FTSE
# Date
# 2025-08-18 -0.000101  0.000314 -0.001828  0.002057
# 2025-08-19 -0.005858 -0.014555  0.004454  0.003440
# 2025-08-20 -0.002432 -0.006666 -0.005982  0.010763
# 2025-08-21 -0.004004 -0.003427  0.000674  0.002272
# 2025-08-22  0.015186  0.018778  0.002871  0.001311

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.103559
# ^IXIC     0.138634
# ^GDAXI    0.093329
# ^FTSE     0.049111
# dtype: float64

# %%
tickers = ['PG','^GSPC','^DJI']
data_2 = pd.DataFrame()
for t in tickers:
    data_2[t] = yf.download(t, start = '1995-1-1')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2025-08-18  155.720001  6449.149902  44911.820312
# 2025-08-19  158.399994  6411.370117  44922.269531
# 2025-08-20  159.509995  6395.779785  44938.308594
# 2025-08-21  158.729996  6370.169922  44785.500000
# 2025-08-22  158.669998  6466.910156  45631.738281

# %%
(data_2 / data_2.iloc[0]*100).plot(figsize=(15,6));
